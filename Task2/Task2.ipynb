# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import *
from sklearn.linear_model import *
from sklearn.preprocessing import *
from sklearn.metrics import *
import sklearn
from sklearn import linear_model
from sklearn import tree 
from sklearn import ensemble
import xgboost

# %%
dataset_white=pd.read_csv(r'winequality-white.csv',sep=None,engine='python')
dataset_red=pd.read_csv(r'winequality-red.csv',sep=None,engine='python')

# %%
dataset_white.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
y = dataset_white['quality'].values
X = dataset_white.drop(columns = ['quality'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train = StandardScaler().fit(X_train).transform(X_train)
X_test = StandardScaler().fit(X_test).transform(X_test)

# %%
def run_models(models,X_train,y_train,X_test,y_test):
    for model in models:
        model = model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        print("\n\nModel:", model.__class__.__name__)
        print("Train Score : ",model.score(X_train, y_train))
        print("Test Score : ",r2_score(y_test,y_pred))

# %% [markdown]
# # Since we have multitask option available, we can fit both red wine and white wine models together

# %% [markdown]
# # Linear Regression Models

# %%
LR = LinearRegression()
R = Ridge()
RCV = RidgeCV()
SGD = SGDRegressor()
L = linear_model.Lasso()
EN = linear_model.ElasticNet()
HR = linear_model.HuberRegressor()
LSVR = sklearn.svm.LinearSVR(max_iter=10000)
DTR = tree.DecisionTreeRegressor()
ETR = tree.ExtraTreeRegressor()

linear_models = [LR,R,RCV,SGD,L,EN,HR,LSVR,DTR,ETR]

# %%
run_models(linear_models,X_train,y_train,X_test,y_test)
# Out:
# Model: LinearRegression
# Train Score :  0.2879431225091068
# Test Score :  0.2506416786605612
#
#
# Model: Ridge
# Train Score :  0.28794088486195923
# Test Score :  0.2509695974252484
#
#
# Model: RidgeCV
# Train Score :  0.2879408848619589
# Test Score :  0.25096959742516267
#
#
# Model: SGDRegressor
# Train Score :  0.28444103403339216
# Test Score :  0.2579648176832442
#
#
# Model: Lasso
# Train Score :  0.0
# Test Score :  -0.005656503687872849
#
#
# Model: ElasticNet
# Train Score :  0.0
# Test Score :  -0.005656503687872849
#
#
# Model: HuberRegressor
# Train Score :  0.2855640385989474
# Test Score :  0.25403100779974286
#
#
# Model: LinearSVR
# Train Score :  0.2805188524702731
# Test Score :  0.25217482520484713
#
#
# Model: DecisionTreeRegressor
# Train Score :  1.0
# Test Score :  -0.058176555716353384
#
#
# Model: ExtraTreeRegressor
# Train Score :  1.0
# Test Score :  0.1224312590448623

# %% [markdown]
# # Non-linear Regression Models

# %%
NuSVR = sklearn.svm.NuSVR()
ESVR = sklearn.svm.SVR()
RFR = ensemble.RandomForestRegressor()
XGB = xgboost.XGBRegressor()
non_linear_models = [NuSVR,ESVR,RFR,XGB]

# %%
run_models(non_linear_models,X_train,y_train,X_test,y_test)
